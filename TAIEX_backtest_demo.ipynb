# %% [markdown]
# # TAIEX 策略回測（Demo）
#
# 這是一個示範用的 Jupyter Notebook。
# - 之後你可以把本地的程式碼、KPI、圖表貼進來。
# - 目前先放一個簡單的範例 code cell。

# %%
from datetime import date
print("Notebook OK —", date.today())
kpi = {
    "initial_equity": 100000,
    "terminal_equity": 123456,
    "total_return": 0.2345,
    "cagr": 0.15,
}
kpi
